# %%
import os
os.getcwd()
os.chdir('D:/Github Repos/My-Kaggle-Solutions/Titanic')
os.getcwd()
# Out:
# 'D:\\Github Repos\\My-Kaggle-Solutions\\Titanic'

# %%
# Importing libraries
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test    = pd.read_csv("test.csv")
full = test.append(train, ignore_index = True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500     N
# 1            2         1       1  female  38.0      1      0  71.2833     C
# 2            3         1       3  female  26.0      0      0   7.9250     N
# 3            4         1       1  female  35.0      1      0  53.1000     C
# 4            5         0       3    male  35.0      0      0   8.0500     N
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
train = train.drop(['Ticket', 'Name'], axis=1)
train.Cabin = train.Cabin.fillna('N')
train.Cabin = train.Cabin.apply(lambda x: x[0])


# NEED TO ENCODE THE DATA AND THEN RUN FEATURE ENGINEERING

# %%
train.describe() # Very powerful feature
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %% [markdown]
# ### Plotting the training data

# %%
sns.barplot(x = 'Embarked', y ='Survived', hue = 'Sex', data = train ) # plotting the data. 

# The trend shows that more female passengers were saved than were male

# %%
train.Survived.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
correlation_matrix = train.corr()
plt.figure(figsize=(10,8))
ax = sns.heatmap(correlation_matrix, vmax=1, square=True,annot=True,cmap='RdYlGn')
plt.title('Correlation matrix between the features')
plt.show()

# P class, Parch, Age , 
# need to modify the data set, so that more features can be put in the correlatiopn matrix
